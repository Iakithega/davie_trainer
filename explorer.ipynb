# %%
import pandas as pd
from utils.data_engineering import *

# %%
path_to_excel = 'data\davie trainingsplan 2014.xlsx'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\danja\AppData\Local\Temp\ipykernel_59920\2477162406.py:1: SyntaxWarning: invalid escape sequence '\d'
#   path_to_excel = 'data\davie trainingsplan 2014.xlsx'

# %%
def load_raw_excel(path: str):
    data = pd.read_excel(path_to_excel, 
                         header=0, 
                         index_col="Datum", 
                         parse_dates=True)
    return data

# %%
initial_data = load_raw_excel(path_to_excel)

# %%
initial_data = weight_reps_exctracter(initial_data)

# %%
initial_data
# Out:
#             Planke set 1  Planke set 2  Planke set 3  Planke set 4  \
# Datum
# 2024-08-11          70.0          70.0           NaN           NaN
# 2024-08-12           NaN           NaN           NaN           NaN
# 2024-08-13           NaN           NaN           NaN           NaN
# 2024-08-14          80.0          80.0           NaN           NaN
# 2024-08-15           NaN           NaN           NaN           NaN
# 2024-08-16          85.0          85.0           NaN           NaN
# 2024-08-17           NaN           NaN           NaN           NaN
# 2024-08-18           NaN           NaN           NaN           NaN
#
#             Liegestütz set 1  Liegestütz set 2  Liegestütz set 3  \
# Datum
# 2024-08-11              10.0               8.0               NaN
# 2024-08-12               NaN               NaN               NaN
# 2024-08-13               NaN               NaN               NaN
# 2024-08-14               8.0               8.0               NaN
# ...
